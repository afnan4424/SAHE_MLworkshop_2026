# %%
#import libraries 
import numpy as np #Faster Data processing (arrays)
import pandas as pd #EDA Purpose

# %%
#loading the data
data = pd.read_csv ("titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
data.dtypes
data.select_dtypes(include='object')#object columns
data.select_dtypes(include=['int','float'])
# Out:
# C:\Users\afnan\AppData\Local\Temp\ipykernel_27632\1036365700.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object')#object columns
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
print('total number of passengers in the ship are',len(data))
# Out:
# total number of passengers in the ship are 891

# %%
data.describe() #default -->numerical columns only
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='object')
# Out:
# C:\Users\afnan\AppData\Local\Temp\ipykernel_27632\3382516499.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include='object')
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
data['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: str

# %%
data['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
data['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
data['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data['Age'].value_counts().head(30)
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 28.0    25
# 19.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 26.0    18
# 35.0    18
# 27.0    18
# 32.0    18
# 31.0    17
# 16.0    17
# 20.0    15
# 34.0    15
# 33.0    15
# 23.0    15
# 39.0    14
# 40.0    13
# 42.0    13
# 17.0    13
# 45.0    12
# 38.0    11
# 2.0     10
# 4.0     10
# 50.0    10
# 47.0     9
# Name: count, dtype: int64

# %%
data.sample(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 482          483         0       3
# 104          105         0       3
# 795          796         0       2
# 671          672         0       1
# 568          569         0       3
# 794          795         0       3
# 40            41         0       3
# 738          739         0       3
# 538          539         0       3
# 405          406         0       2
# 160          161         0       3
# 11            12         1       1
# 50            51         0       3
# 621          622         1       1
# 439          440         0       2
#
#                                                Name     Sex   Age  SibSp  \
# 482                        Rouse, Mr. Richard Henry    male  50.0      0
# 104                  Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 795                              Otter, Mr. Richard    male  39.0      0
# 671                          Davidson, Mr. Thornton    male  31.0      1
# 568                             Doharr, Mr. Tannous    male   NaN      0
# 794                           Dantcheff, Mr. Ristiu    male  25.0      0
# 40   Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 738                              Ivanoff, Mr. Kanio    male   NaN      0
# 538                        Risien, Mr. Samuel Beard    male   NaN      0
# 405                              Gale, Mr. Shadrach    male  34.0      1
# 160                        Cribb, Mr. John Hatfield    male  44.0      0
# 11                         Bonnell, Miss. Elizabeth  female  58.0      0
# 50                       Panula, Master. Juha Niilo    male   7.0      4
# 621                    Kimball, Mr. Edwin Nelson Jr    male  42.0      1
# 439          Kvillner, Mr. Johan Henrik Johannesson    male  31.0      0
#
#      Parch      Ticket     Fare Cabin Embarked
# 482      0    A/5 3594   8.0500   NaN        S
# 104      0     3101276   7.9250   NaN        S
# 795      0       28213  13.0000   NaN        S
# 671      0  F.C. 12750  52.0000   B71        S
# 568      0        2686   7.2292   NaN        C
# 794      0      349203   7.8958   NaN        S
# 40       0        7546   9.4750   NaN        S
# 738      0      349201   7.8958   NaN        S
# 538      0      364498  14.5000   NaN        S
# 405      0       28664  21.0000   NaN        S
# 160      1      371362  16.1000   NaN        S
# 11       0      113783  26.5500  C103        S
# 50       1     3101295  39.6875   NaN        S
# 621      0       11753  52.5542   D19        S
# 439      0  C.A. 18723  10.5000   NaN        S

# %%
 pip install matplot
# Out:
# Collecting matplot
#   Downloading matplot-0.1.9-py2.py3-none-any.whl.metadata (241 bytes)
# Collecting pyloco>=0.0.134 (from matplot)
#   Downloading pyloco-0.0.139-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting matplotlib>=3.1.1 (from matplot)
#   Downloading matplotlib-3.11.1-cp312-cp312-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.1.1->matplot)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.1.1->matplot)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib>=3.1.1->matplot)
#   Downloading fonttools-4.63.0-cp312-cp312-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.1.1->matplot)
#   Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from matplotlib>=3.1.1->matplot) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from matplotlib>=3.1.1->matplot) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from matplotlib>=3.1.1->matplot) (12.3.0)
# Collecting pyparsing>=3 (from matplotlib>=3.1.1->matplot)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from matplotlib>=3.1.1->matplot) (2.9.0.post0)
# Collecting ushlex (from pyloco>=0.0.134->matplot)
#   Downloading ushlex-0.99.1.tar.gz (4.7 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: websocket-client in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from pyloco>=0.0.134->matplot) (1.9.0)
# Collecting twine (from pyloco>=0.0.134->matplot)
#   Downloading twine-7.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting typing (from pyloco>=0.0.134->matplot)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting SimpleWebSocketServer (from pyloco>=0.0.134->matplot)
#   Downloading SimpleWebSocketServer-0.1.2.tar.gz (10 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: six>=1.5 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.17.0)
# Collecting readme-renderer>=35.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading readme_renderer-45.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: requests>=2.20 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.34.2)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: urllib3>=1.26.0 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.7.0)
# Collecting keyring>=21.2.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading keyring-25.7.0-py3-none-any.whl.metadata (21 kB)
# Collecting rfc3986>=1.4.0 (from twine->pyloco>=0.0.134->matplot)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting rich>=14.3.3 (from twine->pyloco>=0.0.134->matplot)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting id (from twine->pyloco>=0.0.134->matplot)
#   Downloading id-1.6.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting pywin32-ctypes>=0.2.0 (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot)
#   Downloading pywin32_ctypes-0.2.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting jaraco.classes (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting jaraco.functools (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco_functools-4.6.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting jaraco.context (from keyring>=21.2.0->twine->pyloco>=0.0.134->matplot)
#   Downloading jaraco_context-6.1.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading nh3-0.3.6-cp38-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting docutils>=0.21.2 (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot)
#   Downloading docutils-0.23-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: Pygments>=2.5.1 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2026.7.22)
# Collecting markdown-it-py>=2.2.0 (from rich>=14.3.3->twine->pyloco>=0.0.134->matplot)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=14.3.3->twine->pyloco>=0.0.134->matplot)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting more-itertools (from jaraco.classes->keyring>=21.2.0->twine->pyloco>=0.0.134->matplot)
#   Downloading more_itertools-11.1.0-py3-none-any.whl.metadata (41 kB)
# Downloading matplot-0.1.9-py2.py3-none-any.whl (5.0 kB)
# Downloading matplotlib-3.11.1-cp312-cp312-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.3 MB 1.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/9.3 MB 1.8 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.3 MB 2.0 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/9.3 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/9.3 MB 2.4 MB/s eta 0:00:03
#    --------------- ------------------------ 3.7/9.3 MB 2.6 MB/s eta 0:00:03
#    -------------------- ------------------- 4.7/9.3 MB 2.9 MB/s eta 0:00:02
#    ------------------------ --------------- 5.8/9.3 MB 3.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.8/9.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.3 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.3 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 3.3 MB/s  0:00:02
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 4.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.3 MB 3.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 2.6 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pyloco-0.0.139-py2.py3-none-any.whl (60 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading twine-7.0.0-py3-none-any.whl (43 kB)
# Downloading keyring-25.7.0-py3-none-any.whl (39 kB)
# Downloading pywin32_ctypes-0.2.3-py3-none-any.whl (30 kB)
# Downloading readme_renderer-45.0-py3-none-any.whl (14 kB)
# Downloading docutils-0.23-py3-none-any.whl (634 kB)
#    ---------------------------------------- 0.0/634.7 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/634.7 kB ? eta -:--:--
#    ---------------------------------------- 634.7/634.7 kB 2.0 MB/s  0:00:00
# Downloading nh3-0.3.6-cp38-abi3-win_amd64.whl (624 kB)
#    ---------------------------------------- 0.0/624.5 kB ? eta -:--:--
#    --------------------------------- ------ 524.3/624.5 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 624.5/624.5 kB 2.1 MB/s  0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading id-1.6.1-py3-none-any.whl (14 kB)
# Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Downloading jaraco_context-6.1.2-py3-none-any.whl (7.9 kB)
# Downloading jaraco_functools-4.6.0-py3-none-any.whl (11 kB)
# Downloading more_itertools-11.1.0-py3-none-any.whl (72 kB)
# Building wheels for collected packages: SimpleWebSocketServer, typing, ushlex
#   Building wheel for SimpleWebSocketServer (pyproject.toml): started
#   Building wheel for SimpleWebSocketServer (pyproject.toml): finished with status 'done'
#   Created wheel for SimpleWebSocketServer: filename=simplewebsocketserver-0.1.2-py3-none-any.whl size=9741 sha256=c7912bfd6be0887c9830a16ca2101213944861261ad79a827e025de3858fce70
#   Stored in directory: c:\users\afnan\appdata\local\pip\cache\wheels\81\fd\d8\f145b47bedceb5dff96b76e404a4ee9be956a4f8f150cd8133
#   Building wheel for typing (pyproject.toml): started
#   Building wheel for typing (pyproject.toml): finished with status 'done'
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26420 sha256=8ea2bf6af4a5920971bfd175913c19c6fccc5048904ba08c4a45e8e254375063
#   Stored in directory: c:\users\afnan\appdata\local\pip\cache\wheels\12\98\52\2bffe242a9a487f00886e43b8ed8dac46456702e11a0d6abef
#   Building wheel for ushlex (pyproject.toml): started
#   Building wheel for ushlex (pyproject.toml): finished with status 'done'
#   Created wheel for ushlex: filename=ushlex-0.99.1-py3-none-any.whl size=4443 sha256=5dabd8d51ddc66707c1083b8484e2ee8f5cb1e7ca61b89a6c7c04ca4be05f254
#   Stored in directory: c:\users\afnan\appdata\local\pip\cache\wheels\42\29\49\bde2276505cc99295263e8ab2fbfd83162b3380b4b571b03bc
# Successfully built SimpleWebSocketServer typing ushlex
# Installing collected packages: ushlex, SimpleWebSocketServer, typing, rfc3986, pywin32-ctypes, pyparsing, nh3, more-itertools, mdurl, kiwisolver, jaraco.context, id, fonttools, docutils, cycler, contourpy, requests-toolbelt, readme-renderer, matplotlib, markdown-it-py, jaraco.functools, jaraco.classes, rich, keyring, twine, pyloco, matplot
#
#    - --------------------------------------  1/27 [SimpleWebSocketServer]
#    -- -------------------------------------  2/27 [typing]
#    ---- -----------------------------------  3/27 [rfc3986]
#    ---- -----------------------------------  3/27 [rfc3986]
#    ---- -----------------------------------  3/27 [rfc3986]
#    ---- -----------------------------------  3/27 [rfc3986]
#    ---- -----------------------------------  3/27 [rfc3986]
#    ---- -----------------------------------  3/27 [rfc3986]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ----- ----------------------------------  4/27 [pywin32-ctypes]
#    ------- --------------------------------  5/27 [pyparsing]
#    ------- --------------------------------  5/27 [pyparsing]
#    ------- --------------------------------  5/27 [pyparsing]
#    ------- --------------------------------  5/27 [pyparsing]
#    ------- --------------------------------  5/27 [pyparsing]
#    ------- --------------------------------  5/27 [pyparsing]
#    ------- --------------------------------  5/27 [pyparsing]
#    ------- --------------------------------  5/27 [pyparsing]
#    -------- -------------------------------  6/27 [nh3]
#    -------- -------------------------------  6/27 [nh3]
#    ---------- -----------------------------  7/27 [more-itertools]
#    ---------- -----------------------------  7/27 [more-itertools]
#    ----------- ----------------------------  8/27 [mdurl]
#    ----------- ----------------------------  8/27 [mdurl]
#    ------------- --------------------------  9/27 [kiwisolver]
#    -------------- ------------------------- 10/27 [jaraco.context]
#    ---------------- ----------------------- 11/27 [id]
#    ---------------- ----------------------- 11/27 [id]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ----------------- ---------------------- 12/27 [fonttools]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ------------------- -------------------- 13/27 [docutils]
#    ---------------------- ----------------- 15/27 [contourpy]
#    ---------------------- ----------------- 15/27 [contourpy]
#    ---------------------- ----------------- 15/27 [contourpy]
#    ---------------------- ----------------- 15/27 [contourpy]
#    ---------------------- ----------------- 15/27 [contourpy]
#    ---------------------- ----------------- 15/27 [contourpy]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ----------------------- ---------------- 16/27 [requests-toolbelt]
#    ------------------------- -------------- 17/27 [readme-renderer]
#    ------------------------- -------------- 17/27 [readme-renderer]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    -------------------------- ------------- 18/27 [matplotlib]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ---------------------------- ----------- 19/27 [markdown-it-py]
#    ----------------------------- ---------- 20/27 [jaraco.functools]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    -------------------------------- ------- 22/27 [rich]
#    ---------------------------------- ----- 23/27 [keyring]
#    ---------------------------------- ----- 23/27 [keyring]
#    ---------------------------------- ----- 23/27 [keyring]
#    ---------------------------------- ----- 23/27 [keyring]
#    ---------------------------------- ----- 23/27 [keyring]
#    ---------------------------------- ----- 23/27 [keyring]
#    ----------------------------------- ---- 24/27 [twine]
#    ----------------------------------- ---- 24/27 [twine]
#    ----------------------------------- ---- 24/27 [twine]
#    ----------------------------------- ---- 24/27 [twine]
#    ------------------------------------- -- 25/27 [pyloco]
#    ------------------------------------- -- 25/27 [pyloco]
#    ------------------------------------- -- 25/27 [pyloco]
#    ------------------------------------- -- 25/27 [pyloco]
#    -------------------------------------- - 26/27 [matplot]
#    ---------------------------------------- 27/27 [matplot]
#
# Successfully installed SimpleWebSocketServer-0.1.2 contourpy-1.3.3 cycler-0.12.1 docutils-0.23 fonttools-4.63.0 id-1.6.1 jaraco.classes-3.4.0 jaraco.context-6.1.2 jaraco.functools-4.6.0 keyring-25.7.0 kiwisolver-1.5.0 markdown-it-py-4.2.0 matplot-0.1.9 matplotlib-3.11.1 mdurl-0.1.2 more-itertools-11.1.0 nh3-0.3.6 pyloco-0.0.139 pyparsing-3.3.2 pywin32-ctypes-0.2.3 readme-renderer-45.0 requests-toolbelt-1.0.0 rfc3986-2.0.0 rich-15.0.0 twine-7.0.0 typing-3.7.4.3 ushlex-0.99.1
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.hist(data['Age'],bins=15,color='red')
plt.xlabel("Age")
plt.ylabel("count")
plt.title("Age Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 plt.hist(data['Age'],bins=15,color='red')
#       2 plt.xlabel("Age")
#       3 plt.ylabel("count")
#       4 plt.title("Age Distribution")
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.hist(data['Age'],bins=15,color='red')
plt.xlabel("Age")
plt.ylabel("count")
plt.title("Age Distribution")
plt.show()

# %%
counts,edges,bars=plt.hist(data['Age'],bins=15,color='purple')
print(counts)
print(bars)
plt.xlabel("Age")
plt.ylabel("count")
plt.bar_label(bars)
plt.title("Age Distribution")
plt.show()
# Out:
# [ 44.  24.  32. 104. 115. 127.  80.  59.  49.  30.  22.  17.   4.   6.
#    1.]
# <BarContainer object of 15 artists>

# %%
#data plot representation
data['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
data['Pclass'].value_counts().plot(kind='barh',color='pink')
# Out:
# <Axes: ylabel='Pclass'>

# %%
plt.bar(data['Survived'],data['Sex'])
plt.xlabel("Survived Rate")
plt.ylabel("Gender")
plt.title("Gender Survived Distribution")
plt.show()

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
#549/(549%342)
index=data['Survived'].value_counts().keys().tolist()
print(index)
labels=data['Survived'].value_counts().values.tolist()
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
plt.pie(x=labels,labels=['Dead','Alive'],
        colors=['pink','lightgreen'],
        autopct="%.1f%%",
       shadow=True)
plt.title("survived rate")
plt.legend()
plt.show()

# %%
plt.pie(x=[577,314],labels=['Male','Female'],
        colors=['violet','red'],
        autopct="%.1f%%",
       shadow=True)
plt.title("survived rate")
plt.legend()
plt.show()

# %%
#pairwise relationship -->scatterplot()
plt.scatter(x=data['Age'],
            y=data['Fare'])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Age vs Fare Distribution')
plt.show()

# %%
import plotly

# %%
# !pip install cufflinks
# Out:
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.9.2 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from cufflinks) (2.5.1)
# Requirement already satisfied: pandas>=0.19.2 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from cufflinks) (3.0.5)
# Requirement already satisfied: plotly>=4.1.1 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from cufflinks) (6.9.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from cufflinks) (1.17.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# Collecting setuptools>=34.4.1 (from cufflinks)
#   Using cached setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: ipython>=5.3.0 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from cufflinks) (9.16.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from cufflinks) (8.1.8)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.53)
# Requirement already satisfied: psutil>=7 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.16.1)
# Requirement already satisfied: wcwidth>=0.1.4 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: comm>=0.1.3 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2026.3)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from plotly>=4.1.1->cufflinks) (2.24.0)
# Requirement already satisfied: packaging in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from plotly>=4.1.1->cufflinks) (26.3)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.2)
# Requirement already satisfied: pure-eval in C:\Users\afnan\ml_workshop_env\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)
# Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Using cached setuptools-83.0.0-py3-none-any.whl (1.0 MB)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (pyproject.toml): started
#   Building wheel for cufflinks (pyproject.toml): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68558 sha256=04b6f3b7968fa3f9ab9c7c3a9c584bc84f63a5e7628c800fc4265dde82c83350
#   Stored in directory: c:\users\afnan\appdata\local\pip\cache\wheels\c0\d9\70\372130dacf508192607c1a7359c7bf0656b1a3b79f6cf66f7a
# Successfully built cufflinks
# Installing collected packages: colorlover, setuptools, cufflinks
#
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    -------------------------- ------------- 2/3 [cufflinks]
#    -------------------------- ------------- 2/3 [cufflinks]
#    -------------------------- ------------- 2/3 [cufflinks]
#    -------------------------- ------------- 2/3 [cufflinks]
#    -------------------------- ------------- 2/3 [cufflinks]
#    -------------------------- ------------- 2/3 [cufflinks]
#    ---------------------------------------- 3/3 [cufflinks]
#
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3 setuptools-83.0.0

# %%
import plotly as py
import plotly.graph_objects as go #for interactive graphs

# %%
#lets visualize histogram 
trace = go.Histogram(x=data['SibSp'],
                     nbinsx=20,
                     marker={'color':'red'})
#layout define for the graph
layout=go.Layout(title="Age Distribution")
#we combine the trace with the layout to display the figure
fig=go.Figure(data=trace,layout=layout)
fig

# %%
print(index)
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
#now we will display for piechart
trace=go.Pie(labels=['Dead','Alive'],
             values=[549,342],)
layout=go.Layout(title='Survived Distribution')
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
#Box plot and Scatter plot
trace = go.Box(x=data['Pclass'],
               y=data['Age'],
               marker={'color':'red'})
layout = go.Layout(title="Age vs Pclass Distribution")
fig =go.Figure(data=trace,layout=layout)
fig.show()

# %%
#Scatter plot representation --> Age vs Fare
trace= go.Scatter(x=data['Age'],y=data['Fare'],
                  mode='markers',
                  marker={'color':'violet'})
layout=go.Layout(title="age vs pclass distribution")
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
#understanding the missing values and filling the missing values
data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
data.isnull().sum()
data['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
#we can fill the age column missing values with mean 
data.
data['Age'].isnull().sum()
# Out:
# C:\Users\afnan\AppData\Local\Temp\ipykernel_27632\2899566619.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data['Age']=data['Age'].fillna(data['Age'].mean(),inplace=True)
# np.int64(0)

# %%
data['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Embarked']=data['Embarked'].fillna('S')

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
data.drop(columns=['Cabin'],inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64
